# %%
#the following code implements the linear regressor y = f(x,theta) = b0 + b1x +...+bmx, N = 10, m = 2
import numpy as np
import matplotlib.pyplot as plt

#Number of training samples = N
N = 10

#Number of parameters = m+1
m = 2

#Generate equispaced samples in the interval [0,2pi] (both 0 and 2*pi excluded)
x = np.linspace(2*np.pi/(N+1),2*np.pi,N,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y = np.sin(x)

#Add noise
y += np.random.normal(mean,std,N)

#Constructing X matrix
X = np.ones(N)
for i in range(m):
    X = np.append(X,x**(i+1))
X = np.reshape(X,(m+1,N))
X = np.transpose(X)

#B = [b0]
#    [b1]
#    [b2]
#As derived in class, B = (X_transpose*X)^(-1)*(X_transpose*y)
B = np.matmul(np.linalg.inv(np.matmul(np.transpose(X),X)),np.matmul(np.transpose(X),y))

#Calculating mean square error while training
y_predicted = np.matmul(B,np.transpose(X))
mean_square_error = (1/N)*np.matmul(y_predicted - y, np.transpose(y_predicted - y))
print("Training error = ")
print(mean_square_error)

#Testing steps

#Number of test samples = T
T = 10
x_test = np.linspace(2*np.pi/(T+1),2*np.pi,T,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y_test = np.sin(x_test)

#Add noise
y_test += np.random.normal(mean,std,T)

#Constructing X_test
X_test = np.ones(T)
for i in range(m):
    X_test = np.append(X_test,x_test**(i+1))
X_test = np.reshape(X_test,(m+1,T))
X_test = np.transpose(X_test)

#Predicting the output
y_predicted = np.matmul(B,np.transpose(X_test))

#Calculating mean square error while testing
mean_square_error = (1/T)*np.matmul(y_predicted - y_test, np.transpose(y_predicted - y_test))
print("Testing error = ")
print(mean_square_error)

#Displaying the results
plt.plot(x_test, y_test,'bx', label = 'ground truth')
plt.plot(x_test, y_predicted,'r', label = 'predicted by regressor')
plt.legend(loc="upper right")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial regression model')
plt.show()

#printing observations
print("Observations: The model is underfitting")
# Out:
# Training error =
# 0.12742610969191107
# Testing error =
# 0.10936388528438044
# Observations: The model is underfitting

# %%
#the following code implements the linear regressor y = f(x,theta) = b0 + b1x +...+bmx, N = 100, m = 2
import numpy as np
import matplotlib.pyplot as plt

#Number of training samples = N
N = 100

#Number of parameters = m+1
m = 2

#Generate equispaced samples in the interval [0,2pi] (both 0 and 2*pi excluded)
x = np.linspace(2*np.pi/(N+1),2*np.pi,N,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y = np.sin(x)

#Add noise
y += np.random.normal(mean,std,N)

#Constructing X matrix
X = np.ones(N)
for i in range(m):
    X = np.append(X,x**(i+1))
X = np.reshape(X,(m+1,N))
X = np.transpose(X)

#B = [b0]
#    [b1]
#    [b2]
#As derived in class, B = (X_transpose*X)^(-1)*(X_transpose*y)
B = np.matmul(np.linalg.inv(np.matmul(np.transpose(X),X)),np.matmul(np.transpose(X),y))

#Calculating mean square error while training
y_predicted = np.matmul(B,np.transpose(X))
mean_square_error = (1/N)*np.matmul(y_predicted - y, np.transpose(y_predicted - y))
print("Training error = ")
print(mean_square_error)

#Testing steps

#Number of test samples = T
T = 25
x_test = np.linspace(2*np.pi/(T+1),2*np.pi,T,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y_test = np.sin(x_test)

#Add noise
y_test += np.random.normal(mean,std,T)

#Constructing X_test
X_test = np.ones(T)
for i in range(m):
    X_test = np.append(X_test,x_test**(i+1))
X_test = np.reshape(X_test,(m+1,T))
X_test = np.transpose(X_test)

#Predicting the output
y_predicted = np.matmul(B,np.transpose(X_test))

#Calculating mean square error while testing
mean_square_error = (1/T)*np.matmul(y_predicted - y_test, np.transpose(y_predicted - y_test))
print("Testing error = ")
print(mean_square_error)

#Displaying the results
plt.plot(x_test, y_test,'bx', label = 'ground truth')
plt.plot(x_test, y_predicted,'r', label = 'predicted by regressor')
plt.legend(loc="upper right")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial regression model')
plt.show()

#printing observations
print("Observations: The model is underfitting")
# Out:
# Training error =
# 0.18528708283328668
# Testing error =
# 0.18059836649109495
# Observations: The model is underfitting

# %%
#the following code implements the linear regressor y = f(x,theta) = b0 + b1x +...+bmx, N = 1000, m = 2
import numpy as np
import matplotlib.pyplot as plt

#Number of training samples = N
N = 1000

#Number of parameters = m+1
m = 2

#Generate equispaced samples in the interval [0,2pi] (both 0 and 2*pi excluded)
x = np.linspace(2*np.pi/(N+1),2*np.pi,N,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y = np.sin(x)

#Add noise
y += np.random.normal(mean,std,N)

#Constructing X matrix
X = np.ones(N)
for i in range(m):
    X = np.append(X,x**(i+1))
X = np.reshape(X,(m+1,N))
X = np.transpose(X)

#B = [b0]
#    [b1]
#    [b2]
#As derived in class, B = (X_transpose*X)^(-1)*(X_transpose*y)
B = np.matmul(np.linalg.inv(np.matmul(np.transpose(X),X)),np.matmul(np.transpose(X),y))

#Calculating mean square error while training
y_predicted = np.matmul(B,np.transpose(X))
mean_square_error = (1/N)*np.matmul(y_predicted - y, np.transpose(y_predicted - y))
print("Training error = ")
print(mean_square_error)

#Testing steps

#Number of test samples = T
T = 250
x_test = np.linspace(2*np.pi/(T+1),2*np.pi,T,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y_test = np.sin(x_test)

#Add noise
y_test += np.random.normal(mean,std,T)

#Constructing X_test
X_test = np.ones(T)
for i in range(m):
    X_test = np.append(X_test,x_test**(i+1))
X_test = np.reshape(X_test,(m+1,T))
X_test = np.transpose(X_test)

#Predicting the output
y_predicted = np.matmul(B,np.transpose(X_test))

#Calculating mean square error while testing
mean_square_error = (1/T)*np.matmul(y_predicted - y_test, np.transpose(y_predicted - y_test))
print("Testing error = ")
print(mean_square_error)

#Displaying the results
plt.plot(x_test, y_test,'bx', label = 'ground truth')
plt.plot(x_test, y_predicted,'r', label = 'predicted by regressor')
plt.legend(loc="upper right")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial regression model')
plt.show()

#printing observations
print("Observations: The model is underfitting")
# Out:
# Training error =
# 0.2002745218218764
# Testing error =
# 0.1977871712191352
# Observations: The model is underfitting

# %%
#the following code implements the linear regressor y = f(x,theta) = b0 + b1x +...+bmx, N = 10, m = 3
import numpy as np
import matplotlib.pyplot as plt

#Number of training samples = N
N = 10

#Number of parameters = m+1
m = 3

#Generate equispaced samples in the interval [0,2pi] (both 0 and 2*pi excluded)
x = np.linspace(2*np.pi/(N+1),2*np.pi,N,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y = np.sin(x)

#Add noise
y += np.random.normal(mean,std,N)

#Constructing X matrix
X = np.ones(N)
for i in range(m):
    X = np.append(X,x**(i+1))
X = np.reshape(X,(m+1,N))
X = np.transpose(X)

#B = [b0]
#    [b1]
#    [b2]
#    [b3]
#As derived in class, B = (X_transpose*X)^(-1)*(X_transpose*y)
B = np.matmul(np.linalg.inv(np.matmul(np.transpose(X),X)),np.matmul(np.transpose(X),y))

#Calculating mean square error while training
y_predicted = np.matmul(B,np.transpose(X))
mean_square_error = (1/N)*np.matmul(y_predicted - y, np.transpose(y_predicted - y))
print("Training error = ")
print(mean_square_error)

#Testing steps

#Number of test samples = T
T = 10
x_test = np.linspace(2*np.pi/(T+1),2*np.pi,T,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y_test = np.sin(x_test)

#Add noise
y_test += np.random.normal(mean,std,T)

#Constructing X_test
X_test = np.ones(T)
for i in range(m):
    X_test = np.append(X_test,x_test**(i+1))
X_test = np.reshape(X_test,(m+1,T))
X_test = np.transpose(X_test)

#Predicting the output
y_predicted = np.matmul(B,np.transpose(X_test))

#Calculating mean square error while testing
mean_square_error = (1/T)*np.matmul(y_predicted - y_test, np.transpose(y_predicted - y_test))
print("Testing error = ")
print(mean_square_error)

#Displaying the results
plt.plot(x_test, y_test,'bx', label = 'ground truth')
plt.plot(x_test, y_predicted,'r', label = 'predicted by regressor')
plt.legend(loc="upper right")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial regression model')
plt.show()

#printing observations
print("Observations: The model is perfect fitting")
# Out:
# Training error =
# 0.0009156182600280186
# Testing error =
# 0.002493105483158766
# Observations: The model is perfect fitting

# %%
#the following code implements the linear regressor y = f(x,theta) = b0 + b1x +...+bmx, N = 100, m = 3
import numpy as np
import matplotlib.pyplot as plt

#Number of training samples = N
N = 100

#Number of parameters = m+1
m = 3

#Generate equispaced samples in the interval [0,2pi] (both 0 and 2*pi excluded)
x = np.linspace(2*np.pi/(N+1),2*np.pi,N,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y = np.sin(x)

#Add noise
y += np.random.normal(mean,std,N)

#Constructing X matrix
X = np.ones(N)
for i in range(m):
    X = np.append(X,x**(i+1))
X = np.reshape(X,(m+1,N))
X = np.transpose(X)

#B = [b0]
#    [b1]
#    [b2]
#    [b3]
#As derived in class, B = (X_transpose*X)^(-1)*(X_transpose*y)
B = np.matmul(np.linalg.inv(np.matmul(np.transpose(X),X)),np.matmul(np.transpose(X),y))

#Calculating mean square error while training
y_predicted = np.matmul(B,np.transpose(X))
mean_square_error = (1/N)*np.matmul(y_predicted - y, np.transpose(y_predicted - y))
print("Training error = ")
print(mean_square_error)

#Testing steps

#Number of test samples = T
T = 25
x_test = np.linspace(2*np.pi/(T+1),2*np.pi,T,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y_test = np.sin(x_test)

#Add noise
y_test += np.random.normal(mean,std,T)

#Constructing X_test
X_test = np.ones(T)
for i in range(m):
    X_test = np.append(X_test,x_test**(i+1))
X_test = np.reshape(X_test,(m+1,T))
X_test = np.transpose(X_test)

#Predicting the output
y_predicted = np.matmul(B,np.transpose(X_test))

#Calculating mean square error while testing
mean_square_error = (1/T)*np.matmul(y_predicted - y_test, np.transpose(y_predicted - y_test))
print("Testing error = ")
print(mean_square_error)

#Displaying the results
plt.plot(x_test, y_test,'bx', label = 'ground truth')
plt.plot(x_test, y_predicted,'r', label = 'predicted by regressor')
plt.legend(loc="upper right")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial regression model')
plt.show()

#printing observations
print("Observations: The model is perfect fitting")
# Out:
# Training error =
# 0.005885855131276088
# Testing error =
# 0.0046221242562443825
# Observations: The model is perfect fitting

# %%
#the following code implements the linear regressor y = f(x,theta) = b0 + b1x +...+bmx, N = 1000, m = 3
import numpy as np
import matplotlib.pyplot as plt

#Number of training samples = N
N = 1000

#Number of parameters = m+1
m = 3

#Generate equispaced samples in the interval [0,2pi] (both 0 and 2*pi excluded)
x = np.linspace(2*np.pi/(N+1),2*np.pi,N,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y = np.sin(x)

#Add noise
y += np.random.normal(mean,std,N)

#Constructing X matrix
X = np.ones(N)
for i in range(m):
    X = np.append(X,x**(i+1))
X = np.reshape(X,(m+1,N))
X = np.transpose(X)

#B = [b0]
#    [b1]
#    [b2]
#    [b3]
#As derived in class, B = (X_transpose*X)^(-1)*(X_transpose*y)
B = np.matmul(np.linalg.inv(np.matmul(np.transpose(X),X)),np.matmul(np.transpose(X),y))

#Calculating mean square error while training
y_predicted = np.matmul(B,np.transpose(X))
mean_square_error = (1/N)*np.matmul(y_predicted - y, np.transpose(y_predicted - y))
print("Training error = ")
print(mean_square_error)

#Testing steps

#Number of test samples = T
T = 250
x_test = np.linspace(2*np.pi/(T+1),2*np.pi,T,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y_test = np.sin(x_test)

#Add noise
y_test += np.random.normal(mean,std,T)

#Constructing X_test
X_test = np.ones(T)
for i in range(m):
    X_test = np.append(X_test,x_test**(i+1))
X_test = np.reshape(X_test,(m+1,T))
X_test = np.transpose(X_test)

#Predicting the output
y_predicted = np.matmul(B,np.transpose(X_test))

#Calculating mean square error while testing
mean_square_error = (1/T)*np.matmul(y_predicted - y_test, np.transpose(y_predicted - y_test))
print("Testing error = ")
print(mean_square_error)

#Displaying the results
plt.plot(x_test, y_test,'bx', label = 'ground truth')
plt.plot(x_test, y_predicted,'r', label = 'predicted by regressor')
plt.legend(loc="upper right")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial regression model')
plt.show()

#printing observations
print("Observations: The model is perfect fitting")
# Out:
# Training error =
# 0.0067678551332486
# Testing error =
# 0.0068040877291223574
# Observations: The model is perfect fitting

# %%
#the following code implements the linear regressor y = f(x,theta) = b0 + b1x +...+bmx, N = 10, m = 4
import numpy as np
import matplotlib.pyplot as plt

#Number of training samples = N
N = 10

#Number of parameters = m+1
m = 4

#Generate equispaced samples in the interval [0,2pi] (both 0 and 2*pi excluded)
x = np.linspace(2*np.pi/(N+1),2*np.pi,N,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y = np.sin(x)

#Add noise
y += np.random.normal(mean,std,N)

#Constructing X matrix
X = np.ones(N)
for i in range(m):
    X = np.append(X,x**(i+1))
X = np.reshape(X,(m+1,N))
X = np.transpose(X)

#B = [b0]
#    [b1]
#    [b2]
#    [b3]
#    [b4]
#As derived in class, B = (X_transpose*X)^(-1)*(X_transpose*y)
B = np.matmul(np.linalg.inv(np.matmul(np.transpose(X),X)),np.matmul(np.transpose(X),y))

#Calculating mean square error while training
y_predicted = np.matmul(B,np.transpose(X))
mean_square_error = (1/N)*np.matmul(y_predicted - y, np.transpose(y_predicted - y))
print("Training error = ")
print(mean_square_error)

#Testing steps

#Number of test samples = T
T = 10
x_test = np.linspace(2*np.pi/(T+1),2*np.pi,T,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y_test = np.sin(x_test)

#Add noise
y_test += np.random.normal(mean,std,T)

#Constructing X_test
X_test = np.ones(T)
for i in range(m):
    X_test = np.append(X_test,x_test**(i+1))
X_test = np.reshape(X_test,(m+1,T))
X_test = np.transpose(X_test)

#Predicting the output
y_predicted = np.matmul(B,np.transpose(X_test))

#Calculating mean square error while testing
mean_square_error = (1/T)*np.matmul(y_predicted - y_test, np.transpose(y_predicted - y_test))
print("Testing error = ")
print(mean_square_error)

#Displaying the results
plt.plot(x_test, y_test,'bx', label = 'ground truth')
plt.plot(x_test, y_predicted,'r', label = 'predicted by regressor')
plt.legend(loc="upper right")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial regression model')
plt.show()

#printing observations
print("Observations: The model is perfect fitting")
# Out:
# Training error =
# 0.003127940722110404
# Testing error =
# 0.006718136887011474
# Observations: The model is perfect fitting

# %%
#the following code implements the linear regressor y = f(x,theta) = b0 + b1x +...+bmx, N = 100, m = 4
import numpy as np
import matplotlib.pyplot as plt

#Number of training samples = N
N = 100

#Number of parameters = m+1
m = 4

#Generate equispaced samples in the interval [0,2pi] (both 0 and 2*pi excluded)
x = np.linspace(2*np.pi/(N+1),2*np.pi,N,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y = np.sin(x)

#Add noise
y += np.random.normal(mean,std,N)

#Constructing X matrix
X = np.ones(N)
for i in range(m):
    X = np.append(X,x**(i+1))
X = np.reshape(X,(m+1,N))
X = np.transpose(X)

#B = [b0]
#    [b1]
#    [b2]
#    [b3]
#    [b4]
#As derived in class, B = (X_transpose*X)^(-1)*(X_transpose*y)
B = np.matmul(np.linalg.inv(np.matmul(np.transpose(X),X)),np.matmul(np.transpose(X),y))

#Calculating mean square error while training
y_predicted = np.matmul(B,np.transpose(X))
mean_square_error = (1/N)*np.matmul(y_predicted - y, np.transpose(y_predicted - y))
print("Training error = ")
print(mean_square_error)

#Testing steps

#Number of test samples = T
T = 25
x_test = np.linspace(2*np.pi/(T+1),2*np.pi,T,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y_test = np.sin(x_test)

#Add noise
y_test += np.random.normal(mean,std,T)

#Constructing X_test
X_test = np.ones(T)
for i in range(m):
    X_test = np.append(X_test,x_test**(i+1))
X_test = np.reshape(X_test,(m+1,T))
X_test = np.transpose(X_test)

#Predicting the output
y_predicted = np.matmul(B,np.transpose(X_test))

#Calculating mean square error while testing
mean_square_error = (1/T)*np.matmul(y_predicted - y_test, np.transpose(y_predicted - y_test))
print("Testing error = ")
print(mean_square_error)

#Displaying the results
plt.plot(x_test, y_test,'bx', label = 'ground truth')
plt.plot(x_test, y_predicted,'r', label = 'predicted by regressor')
plt.legend(loc="upper right")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial regression model')
plt.show()

#printing observations
print("Observations: The model is perfect fitting")
# Out:
# Training error =
# 0.006046668054754635
# Testing error =
# 0.0045400824305457926
# Observations: The model is perfect fitting

# %%
#the following code implements the linear regressor y = f(x,theta) = b0 + b1x +...+bmx, N = 1000, m = 4
import numpy as np
import matplotlib.pyplot as plt

#Number of training samples = N
N = 1000

#Number of parameters = m+1
m = 4

#Generate equispaced samples in the interval [0,2pi] (both 0 and 2*pi excluded)
x = np.linspace(2*np.pi/(N+1),2*np.pi,N,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y = np.sin(x)

#Add noise
y += np.random.normal(mean,std,N)

#Constructing X matrix
X = np.ones(N)
for i in range(m):
    X = np.append(X,x**(i+1))
X = np.reshape(X,(m+1,N))
X = np.transpose(X)

#B = [b0]
#    [b1]
#    [b2]
#    [b3]
#    [b4]
#As derived in class, B = (X_transpose*X)^(-1)*(X_transpose*y)
B = np.matmul(np.linalg.inv(np.matmul(np.transpose(X),X)),np.matmul(np.transpose(X),y))

#Calculating mean square error while training
y_predicted = np.matmul(B,np.transpose(X))
mean_square_error = (1/N)*np.matmul(y_predicted - y, np.transpose(y_predicted - y))
print("Training error = ")
print(mean_square_error)

#Testing steps

#Number of test samples = T
T = 250
x_test = np.linspace(2*np.pi/(T+1),2*np.pi,T,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y_test = np.sin(x_test)

#Add noise
y_test += np.random.normal(mean,std,T)

#Constructing X_test
X_test = np.ones(T)
for i in range(m):
    X_test = np.append(X_test,x_test**(i+1))
X_test = np.reshape(X_test,(m+1,T))
X_test = np.transpose(X_test)

#Predicting the output
y_predicted = np.matmul(B,np.transpose(X_test))

#Calculating mean square error while testing
mean_square_error = (1/T)*np.matmul(y_predicted - y_test, np.transpose(y_predicted - y_test))
print("Testing error = ")
print(mean_square_error)

#Displaying the results
plt.plot(x_test, y_test,'bx', label = 'ground truth')
plt.plot(x_test, y_predicted,'r', label = 'predicted by regressor')
plt.legend(loc="upper right")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial regression model')
plt.show()

#printing observations
print("Observations: The model is perfect fitting")
# Out:
# Training error =
# 0.0066440731703149986
# Testing error =
# 0.007379463745832195
# Observations: The model is perfect fitting

# %%
#the following code implements the linear regressor y = f(x,theta) = b0 + b1x +...+bmx, N = 10, m = 5
import numpy as np
import matplotlib.pyplot as plt

#Number of training samples = N
N = 10

#Number of parameters = m+1
m = 5

#Generate equispaced samples in the interval [0,2pi] (both 0 and 2*pi excluded)
x = np.linspace(2*np.pi/(N+1),2*np.pi,N,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y = np.sin(x)

#Add noise
y += np.random.normal(mean,std,N)

#Constructing X matrix
X = np.ones(N)
for i in range(m):
    X = np.append(X,x**(i+1))
X = np.reshape(X,(m+1,N))
X = np.transpose(X)

#B = [b0]
#    [b1]
#    [b2]
#    [b3]
#    [b4]
#    [b5]
#As derived in class, B = (X_transpose*X)^(-1)*(X_transpose*y)
B = np.matmul(np.linalg.inv(np.matmul(np.transpose(X),X)),np.matmul(np.transpose(X),y))

#Calculating mean square error while training
y_predicted = np.matmul(B,np.transpose(X))
mean_square_error = (1/N)*np.matmul(y_predicted - y, np.transpose(y_predicted - y))
print("Training error = ")
print(mean_square_error)

#Testing steps

#Number of test samples = T
T = 10
x_test = np.linspace(2*np.pi/(T+1),2*np.pi,T,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y_test = np.sin(x_test)

#Add noise
y_test += np.random.normal(mean,std,T)

#Constructing X_test
X_test = np.ones(T)
for i in range(m):
    X_test = np.append(X_test,x_test**(i+1))
X_test = np.reshape(X_test,(m+1,T))
X_test = np.transpose(X_test)

#Predicting the output
y_predicted = np.matmul(B,np.transpose(X_test))

#Calculating mean square error while testing
mean_square_error = (1/T)*np.matmul(y_predicted - y_test, np.transpose(y_predicted - y_test))
print("Testing error = ")
print(mean_square_error)

#Displaying the results
plt.plot(x_test, y_test,'bx', label = 'ground truth')
plt.plot(x_test, y_predicted,'r', label = 'predicted by regressor')
plt.legend(loc="upper right")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial regression model')
plt.show()

#printing observations
print("Observations: The model is perfect fitting")
# Out:
# Training error =
# 0.0004427554843237408
# Testing error =
# 0.0052463488890742566
# Observations: The model is perfect fitting

# %%
#the following code implements the linear regressor y = f(x,theta) = b0 + b1x +...+bmx, N = 100, m = 5
import numpy as np
import matplotlib.pyplot as plt

#Number of training samples = N
N = 100

#Number of parameters = m+1
m = 5

#Generate equispaced samples in the interval [0,2pi] (both 0 and 2*pi excluded)
x = np.linspace(2*np.pi/(N+1),2*np.pi,N,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y = np.sin(x)

#Add noise
y += np.random.normal(mean,std,N)

#Constructing X matrix
X = np.ones(N)
for i in range(m):
    X = np.append(X,x**(i+1))
X = np.reshape(X,(m+1,N))
X = np.transpose(X)

#B = [b0]
#    [b1]
#    [b2]
#    [b3]
#    [b4]
#    [b5]
#As derived in class, B = (X_transpose*X)^(-1)*(X_transpose*y)
B = np.matmul(np.linalg.inv(np.matmul(np.transpose(X),X)),np.matmul(np.transpose(X),y))

#Calculating mean square error while training
y_predicted = np.matmul(B,np.transpose(X))
mean_square_error = (1/N)*np.matmul(y_predicted - y, np.transpose(y_predicted - y))
print("Training error = ")
print(mean_square_error)

#Testing steps

#Number of test samples = T
T = 25
x_test = np.linspace(2*np.pi/(T+1),2*np.pi,T,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y_test = np.sin(x_test)

#Add noise
y_test += np.random.normal(mean,std,T)

#Constructing X_test
X_test = np.ones(T)
for i in range(m):
    X_test = np.append(X_test,x_test**(i+1))
X_test = np.reshape(X_test,(m+1,T))
X_test = np.transpose(X_test)

#Predicting the output
y_predicted = np.matmul(B,np.transpose(X_test))

#Calculating mean square error while testing
mean_square_error = (1/T)*np.matmul(y_predicted - y_test, np.transpose(y_predicted - y_test))
print("Testing error = ")
print(mean_square_error)

#Displaying the results
plt.plot(x_test, y_test,'bx', label = 'ground truth')
plt.plot(x_test, y_predicted,'r', label = 'predicted by regressor')
plt.legend(loc="upper right")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial regression model')
plt.show()

#printing observations
print("Observations: The model is perfect fitting")
# Out:
# Training error =
# 0.0021012017090731045
# Testing error =
# 0.00288097914352553
# Observations: The model is perfect fitting

# %%
#the following code implements the linear regressor y = f(x,theta) = b0 + b1x +...+bmx, N = 1000, m = 5
import numpy as np
import matplotlib.pyplot as plt

#Number of training samples = N
N = 1000

#Number of parameters = m+1
m = 5

#Generate equispaced samples in the interval [0,2pi] (both 0 and 2*pi excluded)
x = np.linspace(2*np.pi/(N+1),2*np.pi,N,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y = np.sin(x)

#Add noise
y += np.random.normal(mean,std,N)

#Constructing X matrix
X = np.ones(N)
for i in range(m):
    X = np.append(X,x**(i+1))
X = np.reshape(X,(m+1,N))
X = np.transpose(X)

#B = [b0]
#    [b1]
#    [b2]
#    [b3]
#    [b4]
#    [b5]
#As derived in class, B = (X_transpose*X)^(-1)*(X_transpose*y)
B = np.matmul(np.linalg.inv(np.matmul(np.transpose(X),X)),np.matmul(np.transpose(X),y))

#Calculating mean square error while training
y_predicted = np.matmul(B,np.transpose(X))
mean_square_error = (1/N)*np.matmul(y_predicted - y, np.transpose(y_predicted - y))
print("Training error = ")
print(mean_square_error)

#Testing steps

#Number of test samples = T
T = 250
x_test = np.linspace(2*np.pi/(T+1),2*np.pi,T,endpoint = False)

#Genrate noise
mean = 0
std = 0.05

#Generate some numbers from the sine function
y_test = np.sin(x_test)

#Add noise
y_test += np.random.normal(mean,std,T)

#Constructing X_test
X_test = np.ones(T)
for i in range(m):
    X_test = np.append(X_test,x_test**(i+1))
X_test = np.reshape(X_test,(m+1,T))
X_test = np.transpose(X_test)

#Predicting the output
y_predicted = np.matmul(B,np.transpose(X_test))

#Calculating mean square error while testing
mean_square_error = (1/T)*np.matmul(y_predicted - y_test, np.transpose(y_predicted - y_test))
print("Testing error = ")
print(mean_square_error)

#Displaying the results
plt.plot(x_test, y_test,'bx', label = 'ground truth')
plt.plot(x_test, y_predicted,'r', label = 'predicted by regressor')
plt.legend(loc="upper right")
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial regression model')
plt.show()

#printing observations
print("Observations: The model is perfect fitting")
# Out:
# Training error =
# 0.002557128406062834
# Testing error =
# 0.002390056086361731
# Observations: The model is perfect fitting
